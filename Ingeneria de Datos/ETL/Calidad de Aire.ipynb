# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_calidad_de_aire = pd.read_csv('/content/drive/MyDrive/Proyecto_Henry/PROYECTO_FINAL/Air_Quality_20240729.csv')

# %%
df_calidad_de_aire.drop(columns=['Message'], inplace=True)

# %%
df_calidad_de_aire.head()
# Out:
#    Unique ID  Indicator ID                                   Name  \
# 0     179772           640  Boiler Emissions- Total SO2 Emissions
# 1     179785           640  Boiler Emissions- Total SO2 Emissions
# 2     178540           365                Fine particles (PM 2.5)
# 3     178561           365                Fine particles (PM 2.5)
# 4     823217           365                Fine particles (PM 2.5)
#
#           Measure Measure Info Geo Type Name  Geo Join ID  \
# 0  Number per km2       number         UHF42        409.0
# 1  Number per km2       number         UHF42        209.0
# 2            Mean       mcg/m3         UHF42        209.0
# 3            Mean       mcg/m3         UHF42        409.0
# 4            Mean       mcg/m3         UHF42        409.0
#
#             Geo Place Name          Time Period  Start_Date  Data Value
# 0         Southeast Queens                 2015  01/01/2015         0.3
# 1  Bensonhurst - Bay Ridge                 2015  01/01/2015         1.2
# ...

# %%
df_calidad_de_aire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18025 entries, 0 to 18024
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18025 non-null  int64
#  1   Indicator ID    18025 non-null  int64
#  2   Name            18025 non-null  object
#  3   Measure         18025 non-null  object
#  4   Measure Info    18025 non-null  object
#  5   Geo Type Name   18025 non-null  object
#  6   Geo Join ID     18016 non-null  float64
#  7   Geo Place Name  18016 non-null  object
#  8   Time Period     18025 non-null  object
#  9   Start_Date      18025 non-null  object
#  10  Data Value      18025 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.5+ MB

# %%
df_calidad_de_aire = df_calidad_de_aire.astype({
    "Unique ID": "str",
    "Indicator ID": "str",
    "Geo Join ID": "str"
})

# %%
df_calidad_de_aire["Start_Date"] = pd.to_datetime(df_calidad_de_aire["Start_Date"])

# %%
df_calidad_de_aire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18025 entries, 0 to 18024
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18025 non-null  object
#  1   Indicator ID    18025 non-null  object
#  2   Name            18025 non-null  object
#  3   Measure         18025 non-null  object
#  4   Measure Info    18025 non-null  object
#  5   Geo Type Name   18025 non-null  object
#  6   Geo Join ID     18025 non-null  object
#  7   Geo Place Name  18016 non-null  object
#  8   Time Period     18025 non-null  object
#  9   Start_Date      18025 non-null  datetime64[ns]
#  10  Data Value      18025 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 1.5+ MB

# %%
df_calidad_de_aire["Geo Join ID"].isna().sum()
# Out:
# 0

# %%
df_calidad_de_aire["Geo Join ID"] = df_calidad_de_aire["Geo Join ID"].str.replace(r'\.0$', '', regex=True)

# %%
df_calidad_de_aire[df_calidad_de_aire["Geo Join ID"].str.isnumeric()]
# Out:
#       Unique ID Indicator ID                                   Name  \
# 0        179772          640  Boiler Emissions- Total SO2 Emissions
# 1        179785          640  Boiler Emissions- Total SO2 Emissions
# 2        178540          365                Fine particles (PM 2.5)
# 3        178561          365                Fine particles (PM 2.5)
# 4        823217          365                Fine particles (PM 2.5)
# ...         ...          ...                                    ...
# 18020    816914          643          Annual vehicle miles traveled
# 18021    816913          643          Annual vehicle miles traveled
# 18022    816872          643          Annual vehicle miles traveled
# 18023    816832          643          Annual vehicle miles traveled
# 18024    151658          643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name Geo Join ID  \
# 0      Number per km2           number         UHF42         409
# ...

# %%
df_calidad_de_aire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18025 entries, 0 to 18024
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18025 non-null  object
#  1   Indicator ID    18025 non-null  object
#  2   Name            18025 non-null  object
#  3   Measure         18025 non-null  object
#  4   Measure Info    18025 non-null  object
#  5   Geo Type Name   18025 non-null  object
#  6   Geo Join ID     18025 non-null  object
#  7   Geo Place Name  18016 non-null  object
#  8   Time Period     18025 non-null  object
#  9   Start_Date      18025 non-null  datetime64[ns]
#  10  Data Value      18025 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 1.5+ MB

# %%
df_calidad_de_aire["Data Value"].min()
# Out:
# 0.0

# %%
df_calidad_de_aire["Data Value"].max()
# Out:
# 424.7

# %%
df_calidad_de_aire[df_calidad_de_aire['Data Value'] == df_calidad_de_aire['Data Value'].min()]
# Out:
#       Unique ID Indicator ID                                     Name  \
# 18       130434          640    Boiler Emissions- Total SO2 Emissions
# 3722     828086          661     Asthma hospitalizations due to Ozone
# 4828     179771          640    Boiler Emissions- Total SO2 Emissions
# 5694     179820          641  Boiler Emissions- Total PM2.5 Emissions
# 5808     179861          641  Boiler Emissions- Total PM2.5 Emissions
# 7315     179819          641  Boiler Emissions- Total PM2.5 Emissions
# 8809     179816          641  Boiler Emissions- Total PM2.5 Emissions
# 8999     179814          641  Boiler Emissions- Total PM2.5 Emissions
# 9001     179826          641  Boiler Emissions- Total PM2.5 Emissions
# 9044     179818          641  Boiler Emissions- Total PM2.5 Emissions
# 9111     179828          641  Boiler Emissions- Total PM2.5 Emissions
# 9148     179815          641  Boiler Emissions- Total PM2.5 Emissions
# ...

# %%
df_analizar = df_calidad_de_aire.head(100)

# %%
location = "/content/drive/MyDrive/Proyecto_Henry/PROYECTO_FINAL/Calidad_Aire_Parcial.csv"
df_analizar.to_csv(location, index=False)

# %%
df_calidad_de_aire.isna().sum()
# Out:
# Unique ID         0
# Indicator ID      0
# Name              0
# Measure           0
# Measure Info      0
# Geo Type Name     0
# Geo Join ID       0
# Geo Place Name    9
# Time Period       0
# Start_Date        0
# Data Value        0
# dtype: int64

# %%
location = "/content/drive/MyDrive/Proyecto_Henry/PROYECTO_FINAL/Calidad_Aire.csv"
df_calidad_de_aire.to_csv(location, index=False)
