# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Pepinot\Documents\Henry\Modulos\PROYECTO GRUPAL\Light_duty_vehicles.csv')

# %%
df.head()
# Out:
#    Vehicle ID  Fuel ID                                              Model  \
# 0       13044       45  NSX                                           ...
# 1       12854       45  A3                                            ...
# 2       12842       45  A3 quattro                                    ...
# 3       12783       45  A4 allroad quattro                            ...
# 4       12782       45  A4 quattro                                    ...
#
#    Model Year                           Fuel
# 0        2022  Hybrid Electric
# 1        2022  Hybrid Electric
# 2        2022  Hybrid Electric
# 3        2022  Hybrid Electric
# 4        2022  Hybrid Electric

# %% [markdown]
# Verificacion de nulos

# %%
print(df.isnull().sum())
# Out:
# Vehicle ID    0
# Fuel ID       0
# Model         0
# Model Year    0
# Fuel          0
# dtype: int64

# %% [markdown]
# Frecuencia de tipo de combustible

# %%
fuel_counts = df['Fuel'].value_counts().reset_index()
fuel_counts.columns = ['Fuel', 'Count']

plt.figure(figsize=(10, 6))
sns.barplot(x='Fuel', y='Count', data=fuel_counts, palette='viridis')
plt.title('Distribución de Tipos de Combustible')
plt.xlabel('Tipo de Combustible')
plt.ylabel('Número de Vehículos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Pepinot\AppData\Local\Temp\ipykernel_9364\1247809140.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Fuel', y='Count', data=fuel_counts, palette='viridis')

# %% [markdown]
# Vemos que el combustible más utilizado es el Ethanol (E85) es una fuente de combustible renovable producida por un proceso de fermentación y destilación de azúcares y almidones. Es un biocombustible muy amable con el medio ambiente.
# En segundo lugar nos encontramos con el tipo de combustible Hybrid Electric que combina dos fuentes de energía distintas para propulsarse, es decir, cuenta con al menos un motor eléctrico y un motor a gasolina.
# Y en tercer lugar nos encontramos con el tipo de fuente electrico.
# Este grafico nos demuestra que hay una predominancia de fuentes de combustibles más amables con el medio ambiente.
